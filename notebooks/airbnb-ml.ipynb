# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from scipy.stats import pearsonr

# %%
df = pd.read_csv("../dados/airbnb-feature-eng.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12652 entries, 0 to 12651
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              12652 non-null  int64
#  1   rating          12652 non-null  float64
#  2   reviews         12652 non-null  int64
#  3   price           12652 non-null  int64
#  4   bathrooms       12652 non-null  int64
#  5   beds            12652 non-null  int64
#  6   guests          12652 non-null  int64
#  7   toilet          12652 non-null  int64
#  8   bedrooms        12652 non-null  int64
#  9   studios         12652 non-null  int64
#  10  France          12652 non-null  int64
#  11  Georgia         12652 non-null  int64
#  12  Greece          12652 non-null  int64
#  13  India           12652 non-null  int64
#  14  Italy           12652 non-null  int64
#  15  Japan           12652 non-null  int64
#  16  Morocco         12652 non-null  int64
#  17  Outros          12652 non-null  int64
#  18  Thailand        12652 non-null  int64
#  19  Turkey          12652 non-null  int64
#  20  United Kingdom  12652 non-null  int64
# dtypes: float64(1), int64(20)
# memory usage: 2.0 MB

# %%
X = df['bedrooms'].values
Y = df['price'].values

# %%
plt.scatter(X, Y)
plt.show()

r = pearsonr(X, Y)
print(f'Coeficiente de correlação: {r}')
# Out:
# Coeficiente de correlação: PearsonRResult(statistic=0.38259579607474536, pvalue=0.0)

# %%
#Separando dados de treino e de teste
#utilizamos 70% dos dados para treino e o restante (30%) para teste.
x_train, x_test, y_train, y_test = train_test_split( X, Y, test_size=0.3)

#Precisamos redimensionar os dados para fazer a regressão linear
x_train=x_train.reshape(-1,1)
y_train=y_train.reshape(-1,1)
x_test=x_test.reshape(-1,1)
y_test=y_test.reshape(-1,1)

# %%
#treinando o modelo
reg = LinearRegression()
reg.fit(x_train,y_train)
pred = reg.predict(x_test)

# %%
plt.scatter(X, Y, color="blue")
plt.plot(x_test, pred, color="red")
plt.title("Bedrooms x Price (Dados de Teste)")
plt.xlabel("Bedrooms")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
from sklearn.metrics import r2_score
r2_score(y_test, pred)
# Out:
# 0.1523218095526473
